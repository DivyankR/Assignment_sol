# %% [markdown]
# ## Question 1:

# %%
# RGBA stands for red-green-blue-alpha model in the color.
# RGBA value is a tuple of 4 integers, each ranging from 0 to 255

# %% [markdown]
# ## Question 2:

# %%
from PIL import ImageColor
ImageColor.getcolor('green', 'RGBA')
ImageColor.getcolor('red', 'RGBA')
ImageColor.getcolor('blue', 'RGBA')
# Out:
# (0, 0, 255, 255)

# %% [markdown]
# ## Question 3:

# %%
# a tuple value of four integers: the left edge x-coordinate,
# the top edge y-coordinate, the width, and the height, respectively is box tuple

# %% [markdown]
# ## Question 4:

# %%
# !pip install google.colab

from google.colab import files
uploaded = files.upload()
# Out:
# ...
#      |████████████████████████████████| 72 kB 3.1 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 64 kB 10.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 104 kB 53.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 758 kB 37.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 8.0 MB 217 kB/s eta 0:00:011
# ...
#      |████████████████████████████████| 11.8 MB 3.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 57 kB 14.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 484 kB 13.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 155 kB 59.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 245 kB 40.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 77 kB 16.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 118 kB 33.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 58 kB 25.9 MB/s eta 0:00:01
# ...
#   Using cached chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# ...

# %%
from PIL import Image
myImg = Image.open('sign.jpg')
w,h = myImg.size
w,h
# Out:
# (1340, 728)

# %% [markdown]
# ## Question 5:

# %%
# ImageObject.crop(0,50,50,50)

# %% [markdown]
# ## Question 6:

# %%
# call the mageObj.save('new_filename.png') method

# %% [markdown]
# ## Question 7:

# %%
# ImageDraw module

# %% [markdown]
# ## Question 8:

# %%
# these objects ahve shape drawing methods such as point(), line(), rectangle(). 
# these are returned by passing the image object to the ImageDraw.Draw()
